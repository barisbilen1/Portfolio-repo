# %%
                        ##-- Test data join - 2 --##
# Importing libraries

import pandas as pd
import getpass
import math
import numpy as np
#from tqdm import trange
import gc
#import matplotlib.pyplot as plt
#import seaborn as sns
#from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

if getpass.getuser() == "asus":
    file_path = "C:/Users/asus/Desktop/trendyol_data_v2/"
    
if getpass.getuser() == "your computers name":
    file_path = "C:/Users/..desiredlocation..."

# %%
test_data = pd.read_csv(file_path + 'test_data_final.csv')
user_data = pd.read_csv(file_path + 'user_data.csv')
product_data = pd.read_csv(file_path + 'product_data.csv')

# %%
user_data = pd.read_csv(file_path + 'user_data.csv') #overriding

# %%
gc.collect()
# Out:
# 22

# %%
test_data
# Out:
#        user_id  product_content_id  order_parent_id        is_returned
# 0        18115            87073974        726348863  will_be_predicted
# 1        27588           118753298        723169934  will_be_predicted
# 2        29165            35699988        724122443  will_be_predicted
# 3        29969             5893187        722342150  will_be_predicted
# 4        35107            93897418        723421057  will_be_predicted
# ...        ...                 ...              ...                ...
# 7466  71083899           100019570        728638514  will_be_predicted
# 7467  71106534            35624085        725372928  will_be_predicted
# 7468  71115350            94438742        725291348  will_be_predicted
# 7469  71115350           100017676        725291348  will_be_predicted
# 7470  71160557            87073974        726377172  will_be_predicted
#
# [7471 rows x 4 columns]

# %%
user_data = user_data.drop_duplicates()

# %%
user_data
# Out:
#            user_id  is_elite_user  Bay  Bayan  is_wallet_trx  \
# 0          3941815              0    0      1              0
# 4         15996105              1    0      1              0
# 5         11914979              1    0      1              0
# 13         7087572              0    0      1              0
# 16         3120295              1    0      1              1
# ...            ...            ...  ...    ...            ...
# 10772551   3524182              0    0      1              1
# 10772561  14483581              0    0      1              0
# 10772566  61030570              0    0      1              0
# 10772568  33791403              1    0      1              1
# 10772604  18901074              0    1      0              0
#
#           is_saved_card_trx
# 0                         1
# 4                         0
# 5                         1
# 13                        1
# 16                        0
# ...                     ...
# ...

# %%
#user_data = user_data.drop(['is_wallet_trx'],axis=1)

# %%
test_joined1 = pd.merge(test_data, user_data, on = 'user_id', how = 'left')

# %%
gc.collect()
# Out:
# 22

# %%
test_joined1
# Out:
#         user_id  product_content_id  order_parent_id        is_returned  \
# 0         18115            87073974        726348863  will_be_predicted
# 1         18115            87073974        726348863  will_be_predicted
# 2         18115            87073974        726348863  will_be_predicted
# 3         27588           118753298        723169934  will_be_predicted
# 4         29165            35699988        724122443  will_be_predicted
# ...         ...                 ...              ...                ...
# 14691  71083899           100019570        728638514  will_be_predicted
# 14692  71106534            35624085        725372928  will_be_predicted
# 14693  71115350            94438742        725291348  will_be_predicted
# 14694  71115350           100017676        725291348  will_be_predicted
# 14695  71160557            87073974        726377172  will_be_predicted
#
#        is_elite_user  Bay  Bayan  is_wallet_trx  is_saved_card_trx
# ...

# %%
#user_data = user_data.drop(['is_wallet_trx'],axis=1)
user_data = user_data.drop_duplicates()

# %%
test_joined2 = pd.merge(test_data, user_data, on = 'user_id', how = 'left')

# %%
test_joined2
# Out:
#         user_id  product_content_id  order_parent_id        is_returned  \
# 0         18115            87073974        726348863  will_be_predicted
# 1         18115            87073974        726348863  will_be_predicted
# 2         27588           118753298        723169934  will_be_predicted
# 3         29165            35699988        724122443  will_be_predicted
# 4         29969             5893187        722342150  will_be_predicted
# ...         ...                 ...              ...                ...
# 12466  71083899           100019570        728638514  will_be_predicted
# 12467  71106534            35624085        725372928  will_be_predicted
# 12468  71115350            94438742        725291348  will_be_predicted
# 12469  71115350           100017676        725291348  will_be_predicted
# 12470  71160557            87073974        726377172  will_be_predicted
#
#        is_elite_user  Bay  Bayan  is_saved_card_trx
# ...

# %%
user_data = user_data.drop(['is_elite_user','is_saved_card_trx'],axis=1)
user_data = user_data.drop_duplicates()

# %%
test_joined2 = pd.merge(test_data, user_data, on = 'user_id', how = 'left')

# %%
test_joined2
# Out:
#        user_id  product_content_id  order_parent_id        is_returned  Bay  \
# 0        18115            87073974        726348863  will_be_predicted    0
# 1        27588           118753298        723169934  will_be_predicted    0
# 2        29165            35699988        724122443  will_be_predicted    0
# 3        29969             5893187        722342150  will_be_predicted    0
# 4        35107            93897418        723421057  will_be_predicted    0
# ...        ...                 ...              ...                ...  ...
# 7466  71083899           100019570        728638514  will_be_predicted    0
# 7467  71106534            35624085        725372928  will_be_predicted    0
# 7468  71115350            94438742        725291348  will_be_predicted    0
# 7469  71115350           100017676        725291348  will_be_predicted    0
# 7470  71160557            87073974        726377172  will_be_predicted    0
#
#       Bayan
# 0         1
# 1         1
# 2         1
# ...

# %%
len(test_data) == 7471
# Out:
# True

# %% [markdown]
# We have to sacrifice three columns for the sake of joining tables. \
# We also need to remove those three columns from the model because we cannot use them \
# as predictors anymore.

# %%
gc.collect()
# Out:
# 22

# %%
test_joined2.to_csv(file_path+'test_joined2.csv',index=False)

# %%
#test_joined3 = pd.merge(test_joined2, product_data, on = 'product_content_id', how = 'left')
#gave memory error again, switching notebook.
